# %% [markdown]
# ### Data Ingestion

# %%
# Document Structure

from langchain_core.documents import Document

# %%
doc = Document(
    page_content= "This is the main text content. I am using to create RAG.",
    metadata = {
        "source": "example.txt",
        "pages": 1,
        "author": "Talha Shahid",
        "data_created": "2026-07-19"
    }
)

doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Talha Shahid', 'data_created': '2026-07-19'}, page_content='This is the main text content. I am using to create RAG.')

# %%
# Create a simple text file

import os

os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_text = {
    "../data/text_files/ai_notes.txt":"""Artificial Intelligence Notes

Artificial Intelligence (AI) is the field of computer science that focuses on creating systems capable of performing tasks that normally require human intelligence. These tasks include reasoning, learning, problem-solving, perception, and language understanding.

Machine Learning is a subset of AI where algorithms learn patterns from data instead of following explicitly programmed rules. Common types of machine learning include supervised learning, unsupervised learning, and reinforcement learning.

Deep Learning is a subset of machine learning that uses neural networks with multiple layers. It has achieved state-of-the-art performance in computer vision, speech recognition, and natural language processing.

Natural Language Processing (NLP) enables computers to understand and generate human language. Popular NLP applications include chatbots, translation systems, sentiment analysis, and question-answering systems.

Large Language Models (LLMs) are trained on massive amounts of text data and can perform various language-related tasks. Examples include GPT, Llama, Gemma, and Mistral.

---

# Python Programming

Python is a high-level programming language known for its readability and extensive ecosystem. It is widely used in web development, automation, data science, and machine learning.

Popular Python libraries include:
- NumPy for numerical computing.
- Pandas for data manipulation.
- Matplotlib for visualization.
- Scikit-learn for machine learning.
- PyTorch and TensorFlow for deep learning.
- FastAPI for building APIs.

Virtual environments help isolate project dependencies. Common tools include venv, uv, and conda.

---

# Databases

A database is an organized collection of data.

Relational databases store information in tables with rows and columns. PostgreSQL, MySQL, and SQL Server are popular relational database systems.

NoSQL databases include MongoDB, Redis, and Cassandra. They are often used for flexible schemas and high scalability.

Indexes improve query performance by reducing the amount of data scanned.

Normalization reduces redundancy by organizing data into related tables.

---

# Cloud Computing

Cloud computing provides computing resources over the internet.

The three main cloud service models are:
- Infrastructure as a Service (IaaS)
- Platform as a Service (PaaS)
- Software as a Service (SaaS)

Major cloud providers include AWS, Microsoft Azure, and Google Cloud Platform.

Docker packages applications into containers, while Kubernetes manages containerized applications at scale.

---

# Space Exploration

Mars is the fourth planet from the Sun. It is often called the Red Planet because of iron oxide on its surface.

The Moon is Earth's only natural satellite and has no atmosphere capable of supporting life.

The James Webb Space Telescope was launched to observe distant galaxies and study the early universe.

NASA, ESA, and SpaceX are among the organizations involved in space exploration.

---

# Health and Fitness

Regular exercise improves cardiovascular health, muscle strength, and mental well-being.

Adults are generally encouraged to engage in at least 150 minutes of moderate physical activity per week.

Drinking enough water is important for maintaining body functions.

A balanced diet includes carbohydrates, proteins, healthy fats, vitamins, and minerals.

---

# History

The Industrial Revolution began in the late 18th century and transformed manufacturing through mechanization.

World War II lasted from 1939 to 1945 and involved many nations across the world.

The Internet originated from research projects such as ARPANET before evolving into the global network used today.

---

# Random Facts

Honey never spoils if stored properly.

The Pacific Ocean is the largest ocean on Earth.

Mount Everest is the highest mountain above sea level.

The speed of light in a vacuum is approximately 299,792 kilometers per second.

Bananas are naturally radioactive due to their potassium content.

---

# Software Engineering

Version control systems track changes to code over time.

Git is the most widely used distributed version control system.

GitHub and GitLab provide cloud-based hosting for Git repositories.

Continuous Integration (CI) automatically tests code after changes are pushed.

Continuous Deployment (CD) automates software releases.

Unit tests verify individual components, while integration tests verify interactions between components.

---

# Retrieval-Augmented Generation

RAG combines information retrieval with large language models.

A typical RAG pipeline includes:
1. Document ingestion
2. Text chunking
3. Embedding generation
4. Vector database storage
5. Similarity search
6. Context retrieval
7. LLM response generation

Popular vector databases include ChromaDB, FAISS, Pinecone, Milvus, and Weaviate.

Embedding models convert text into dense numerical vectors that capture semantic meaning.

Chunk size and chunk overlap significantly affect retrieval quality.
    
"""
}

for filepath, content in sample_text.items():
    with open(filepath, 'w', encoding="utf-8") as f:
        f.write(content)
        
print("Sample file created.")
# Out:
# Sample file created.

# %%
# Text Loader

from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/ai_notes.txt", encoding="utf-8")
loader

# %%
document = loader.load()
document
# Out:
# [Document(metadata={'source': '../data/text_files/ai_notes.txt'}, page_content="Artificial Intelligence Notes\n\nArtificial Intelligence (AI) is the field of computer science that focuses on creating systems capable of performing tasks that normally require human intelligence. These tasks include reasoning, learning, problem-solving, perception, and language understanding.\n\nMachine Learning is a subset of AI where algorithms learn patterns from data instead of following explicitly programmed rules. Common types of machine learning include supervised learning, unsupervised learning, and reinforcement learning.\n\nDeep Learning is a subset of machine learning that uses neural networks with multiple layers. It has achieved state-of-the-art performance in computer vision, speech recognition, and natural language processing.\n\nNatural Language Processing (NLP) enables computers to understand and generate human language. Popular NLP applications include chatbots, translation systems, se
# ...

# %%
# Directory 

from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", # pattern to match
    loader_cls=TextLoader, # loader class to use
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=True
)

text_document = dir_loader.load()
text_document
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 1234.71it/s]
# ...

# %%
# Loading PDF

from langchain_community.document_loaders import PyMuPDFLoader, DirectoryLoader

direc_loader = DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf ", # pattern to match
    loader_cls=PyMuPDFLoader # loader class to use
)

# %%
pdf_document = direc_loader.load()
pdf_document
# Out:
# []
